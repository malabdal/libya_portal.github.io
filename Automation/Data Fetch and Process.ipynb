# %%
# imports
import selenium
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome('./chromedriver')
import pandas as pd
import glob
import os.path
import json

# %%
def Upload_Data_as_JSON(URL, New_Name):
    # add country name
    country_name = 'Libya'

    time.sleep(2)
    #Reads the URL 
    driver.get(URL)

    #Waits till the page loads
    time.sleep(60)

    #finds the download button
    s=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div/button/span[1]/div')

    time.sleep(10)

    s.click()

    #Choose to export the data as excel
    c=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div[2]/div[2]/div[2]/li[2]/span[1]')

    time.sleep(10)

    c.click()

    print('Downloading Data')

    time.sleep(60)

    #Specify where the data usually loads and choose the last downloaded file
    folder_path = '../../../../Downloads/'

    file_type = '/*xlsx'
    files = glob.glob(folder_path + file_type)
    max_file = max(files, key=os.path.getctime)


    #Saving the data as dic instead of excel

    df = pd.read_excel(max_file)
    df = df.rename(lambda x: 'Country' if any(k in x for k in ['Country Name', 'Reporter', 'Country ']) else x, axis=1)
    df = df[df['Country'] == country_name]
    df = df.where(pd.notnull(df), None)
    import_file = df.to_dict(orient='records')
    print (import_file)
    
    #Save the file as a json with the name you specified
    with open(New_Name+ '.json', 'w') as fp:
        json.dump(import_file, fp)
    
    return import_file

# %%
#Add the URLs
URLs=[
#     'https://data.unescwa.org/portal/c78f8929-babc-40d9-8d9b-a5438396d3a7', #National Accounts
#     'https://data.unescwa.org/portal/37e07376-dcab-4c77-b25d-b63c6c1c0d4b', #Finance
#     'https://data.unescwa.org/portal/a2f766e6-f2c0-4444-aa73-ccd0d7abf05d', #Trade
#     'https://data.unescwa.org/portal/79a73daa-8d9e-47dd-b1ee-bfed2b22124e', #Transport
#     'https://data.unescwa.org/portal/ae81b7b7-05b5-4b39-b87a-1243bef7b232', #Industry
#     'https://data.unescwa.org/portal/CPI',                                  #CPI
#     'https://data.unescwa.org/portal/a400b071-fd51-4aac-87ae-175627339bdd', #ICP
#     'https://data.unescwa.org/portal/gems_data',                            #GEMS
    'https://data.unescwa.org/portal/7bae8f12-f543-407f-9afa-29471d6b7c6d', #Population
    'https://data.unescwa.org/portal/e68647fb-ea6d-488d-a6f5-2024b080c2cc', #Household Budget
    'https://data.unescwa.org/portal/8c972cac-a80c-4bd4-8208-74c6a092e225', #Health
    'https://data.unescwa.org/portal/e7d41253-2cf5-4f3b-ba5f-6c45b8af1f88', #Education
    'https://data.unescwa.org/portal/69b86687-53d8-4c50-b5d7-b6c96df42d0b', #Labor
    'https://data.unescwa.org/portal/e28b867b-13b6-4d97-ad5e-85264879c2ef', #Environment
    'https://data.unescwa.org/portal/ed5c2876-01e0-492b-9fad-49702ec6d934' #Energy
#     'https://data.unescwa.org/share/618997eb-93eb-466c-b768-50557b5ae7b2' #SDG

    ]

#Names of the new saved data

Names=[
#     'National Accounts',
#     'Finance',
#     'Trade',
#     'Transport',
#     'Industry',
#     'CPI',
#     'ICP',
#     'GEMS',
    'Population',
    'Household Budget',
    'Health',
    'Education',
    'Labor',
    'Environment',
    'Energy'
#     'SDG'

    
    ]

   
for i in range(len(URLs)):
    print("Starting with Document: " ,i)
    Upload_Data_as_JSON(URLs[i], Names[i])
    print("Finished document: " , i)
# Out:
# Starting with Document:  0
# Downloading Data
# /Users/malabdal/opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [{'Indicator': 'Population size (number)', 'Country': 'Libya', 'Age': 'Age Total', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': 4762000.0, '2001': 4848740.0, '2002': 4937281.0, '2003': 5027483.0, '2004': 5119497.0, '2005': 5213000.0, '2006': 5298152.0, '2007': 5393325.0, '2008': 5947749.0, '2009': 5589289.0, '2010': 5689419.0, '2011': 5790519.0, '2012': 5878000.0, '2013': 5994242.0, '2014': 6032000.0, '2015': 6111000.0, '2016': 6190000.0, '2017': 6271000.0, '2018': 6352000.0, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'Libya', 'Age': 'Age Total', 'Sex': 'Female', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': 2346000.0, '2001': 2389428.0, '2002': 2433997.0, '2003': 2479396.0, '2004': 2525771.0, '2005': 2572000.0, '2006': 2610639.0, '2007': 2657982.0, '2008': 3163628.0, '2009': 2755598.0, '2010': 2805538.0, '2011': 2856006.0, '2012': 2851000.0, '2013': 2957849.0, '2014': 3014000.0, '2015': 3068000.0, '2016': 3122000.0, '2017': 3177000.0, '2018': 3131000.0, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'Libya', 'Age': 'Age Total', 'Sex': 'Male', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': 2416000.0, '2001': 2459312.0, '2002': 2503284.0, '2003': 2548042.0, '2004': 2593726.0, '2005': 2641000.0, '2006': 2687513.0, '2007': 2735343.0, '2008': 2784121.0, '2009': 2833691.0, '2010': 2883881.0, '2011': 2934513.0, '2012': 3027000.0, '2013': 3036393.0, '2014': 3059000.0, '2015': 3098000.0, '2016': 3139000.0, '2017': 3180000.0, '2018': 3221000.0, '2019': None}, {'Indicator': 'Average annual population growth rate (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area NA', 'Nationality': 'Nationality NA', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': 1.8051129318029, '2002': 1.80958974304736, '2003': 1.8104686443492, '2004': 1.8136730781171, '2005': 1.80993137481323, '2006': 1.62025747240821, '2007': 1.78039973335623, '2008': 9.7850750805383, '2009': -6.21607409847401, '2010': 1.77560462974152, '2011': 1.76137909117489, '2012': 1.49946431233054, '2013': 1.95827737897901, '2014': 0.627928891913931, '2015': 1.30117952071236, '2016': 1.28446607837262, '2017': 1.3000744864379, '2018': 1.28338923839509, '2019': None}, {'Indicator': 'Population sex ratio (males per 100 females)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area NA', 'Nationality': 'Nationality NA', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': 102.983802216539, '2001': 102.924716710443, '2002': 102.846634568572, '2003': 102.7686581732, '2004': 102.690465604364, '2005': 102.682737169518, '2006': 102.944643054823, '2007': 102.910516324038, '2008': 88.0040573670482, '2009': 102.83397650891, '2010': 102.79244123587, '2011': 102.748838762944, '2012': 106.173272535952, '2013': 102.655443195376, '2014': 101.49303251493, '2015': 100.977835723598, '2016': 100.544522741832, '2017': 100.094428706327, '2018': 102.874480996487, '2019': None}, {'Indicator': 'Average household size (number)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 5.9, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Mean age at first marriage (years)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex':  ...
# Finished document:  0
# Starting with Document:  1
# Downloading Data
# [{'Indicator': 'Social protection expenditure % of GDP (excluding health)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area NA', 'Nationality': 'Nationality NA', 'Quintile': 'Quintile NA', 'Types of products/services': 'Products and services NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 4.4, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}]
# Finished document:  1
# Starting with Document:  2
# Downloading Data
# [{'Indicator': 'Maternal mortality ratio (per 100,000 live births)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': 27.0, '2008': 27.0, '2009': None, '2010': 23.0, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Births attended by skilled health personnel (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': 94.1, '2003': 96.5, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': 100.0, '2010': 100.0, '2011': None, '2012': None, '2013': None, '2014': 98.9, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Antenatal care (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': 89.6, '2003': None, '2004': None, '2005': None, '2006': None, '2007': 93.0, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Use of contraception (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Any method', '2000': None, '2001': None, '2002': None, '2003': 44.5, '2004': None, '2005': None, '2006': None, '2007': 41.9, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': 27.7, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Use of contraception (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Modern method', '2000': None, '2001': None, '2002': None, '2003': 31.4, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': 16.3, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'BCG immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': 91.0, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 100.0, '2011': 100.0, '2012': None, '2013': None, '2014': 96.5, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'DPT immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': 80.7, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 97.7, '2011': 98.66, '2012': None, '2013': None, '2014': 95.8, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'Libya', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nat ...
# Finished document:  2
# Starting with Document:  3
# Downloading Data
# [{'Indicator': 'Adult literacy rates', 'Country': 'Libya', 'Age': '15+ years', 'Sex': 'Both sexes', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 86.1, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Adult literacy rates', 'Country': 'Libya', 'Age': '15+ years', 'Sex': 'Female', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 77.8, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Adult literacy rates', 'Country': 'Libya', 'Age': '15+ years', 'Sex': 'Male', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 93.85, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Youth literacy rates ', 'Country': 'Libya', 'Age': '15-24 years', 'Sex': 'Both sexes', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 99.6, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Youth literacy rates ', 'Country': 'Libya', 'Age': '15-24 years', 'Sex': 'Female', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 99.4, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Youth literacy rates ', 'Country': 'Libya', 'Age': '15-24 years', 'Sex': 'Male', 'Education level': 'Education level NA', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': 99.85, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}]
# Finished document:  3
# Starting with Document:  4
