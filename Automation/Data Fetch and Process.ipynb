# %%
# imports
import selenium
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome('./chromedriver')
import pandas as pd
import glob
import os.path
import json

# %%
def Upload_Data_as_JSON(URL, New_Name):
    # add country name
    country_name = 'Libya'

    time.sleep(2)
    #Reads the URL 
    driver.get(URL)

    #Waits till the page loads
    time.sleep(60)

    #finds the download button
    s=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div/button/span[1]/div')

    time.sleep(10)

    s.click()

    #Choose to export the data as excel
    c=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div[2]/div[2]/div[2]/li[2]/span[1]')

    time.sleep(10)

    c.click()

    print('Downloading Data')

    time.sleep(60)

    #Specify where the data usually loads and choose the last downloaded file
    folder_path = '../../../../Downloads/'

    file_type = '/*xlsx'
    files = glob.glob(folder_path + file_type)
    max_file = max(files, key=os.path.getctime)


    #Saving the data as dic instead of excel

    df = pd.read_excel(max_file)
    df = df.rename(lambda x: 'Country' if any(k in x for k in ['Country Name', 'Reporter', 'Country ']) else x, axis=1)
    df = df[df['Country'] == country_name]
    df = df.where(pd.notnull(df), None)
    import_file = df.to_dict(orient='records')
    print (import_file)
    
    #Save the file as a json with the name you specified
    with open(New_Name+ '.json', 'w') as fp:
        json.dump(import_file, fp)
    
    return import_file

# %%
#Add the URLs
URLs=[
#     'https://data.unescwa.org/portal/c78f8929-babc-40d9-8d9b-a5438396d3a7', #National Accounts
#     'https://data.unescwa.org/portal/37e07376-dcab-4c77-b25d-b63c6c1c0d4b', #Finance
#     'https://data.unescwa.org/portal/a2f766e6-f2c0-4444-aa73-ccd0d7abf05d', #Trade
#     'https://data.unescwa.org/portal/79a73daa-8d9e-47dd-b1ee-bfed2b22124e', #Transport
#     'https://data.unescwa.org/portal/ae81b7b7-05b5-4b39-b87a-1243bef7b232', #Industry
#     'https://data.unescwa.org/portal/CPI',                                  #CPI
#     'https://data.unescwa.org/portal/a400b071-fd51-4aac-87ae-175627339bdd', #ICP
#     'https://data.unescwa.org/portal/gems_data',                            #GEMS
#     'https://data.unescwa.org/portal/7bae8f12-f543-407f-9afa-29471d6b7c6d', #Population
#     'https://data.unescwa.org/portal/e68647fb-ea6d-488d-a6f5-2024b080c2cc', #Household Budget
#     'https://data.unescwa.org/portal/8c972cac-a80c-4bd4-8208-74c6a092e225', #Health
#     'https://data.unescwa.org/portal/e7d41253-2cf5-4f3b-ba5f-6c45b8af1f88', #Education
#     'https://data.unescwa.org/portal/69b86687-53d8-4c50-b5d7-b6c96df42d0b', #Labor
    'https://data.unescwa.org/portal/e28b867b-13b6-4d97-ad5e-85264879c2ef', #Environment
    'https://data.unescwa.org/portal/ed5c2876-01e0-492b-9fad-49702ec6d934' #Energy
#     'https://data.unescwa.org/share/618997eb-93eb-466c-b768-50557b5ae7b2' #SDG

    ]

#Names of the new saved data

Names=[
#     'National Accounts',
#     'Finance',
#     'Trade',
#     'Transport',
#     'Industry',
#     'CPI',
#     'ICP',
#     'GEMS',
#     'Population',
#     'Household Budget',
#     'Health',
#     'Education',
#     'Labor',
    'Environment',
    'Energy'
#     'SDG'

    
    ]

   
for i in range(len(URLs)):
    print("Starting with Document: " ,i)
    Upload_Data_as_JSON(URLs[i], Names[i])
    print("Finished document: " , i)
# Out:
# Starting with Document:  0
# Downloading Data
# /Users/malabdal/opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [{'Country': 'Libya', 'Indicator': 'Fisheries, Production', 'Unit': 'Tons', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': 50069.0, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 37636.0, '2006': 34892.0, '2007': 32166.0, '2008': 47890.0, '2009': 52356.0, '2010': 50246.0, '2011': 30244.0, '2012': 35244.0, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'Fish exports', 'Unit': 'Tons', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': 1913.0, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 3845.0, '2006': 2000.0, '2007': 1137.0, '2008': 1069.0, '2009': 630.0, '2010': 625.0, '2011': 463.0, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'Production in marine areas, Crustaceans', 'Unit': 'Tons', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': 65.0, '2008': 133.0, '2009': 783.0, '2010': 760.0, '2011': 450.0, '2012': 520.0, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'Total CO2 emissions from fuel combustion', 'Unit': 'Metric tons of CO2', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': 44200000.0, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'CO2 emission from road transport', 'Unit': 'Metric tons of CO2', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': 16600000.000000002, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'CO2 emission from residential sector', 'Unit': 'Metric tons of CO2', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': 2100000.0, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'Number of threatened mammal species', 'Unit': 'Units', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': 12.0, '2015': None, '2016': None, '2017': None}, {'Country': 'Libya', 'Indicator': 'Fish exports', 'Unit': 'US Dollars', '1975': None, '1980': None, '1985': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999':  ...
# Finished document:  0
# Starting with Document:  1
# Downloading Data
# [{'Indicator': 'Exports Crude Oil', 'Unit': 'Barrels', 'Country': 'Libya', '1980': None, '1981': None, '1982': None, '1983': None, '1984': None, '1985': None, '1986': None, '1987': None, '1988': None, '1989': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None}, {'Indicator': 'Exports Crude Oil', 'Unit': 'Barrels / Day', 'Country': 'Libya', '1980': 1693000.0, '1981': 1062500.0, '1982': 974000.0, '1983': 937400.0, '1984': 929600.0, '1985': 894600.0, '1986': 1067000.0, '1987': 810000.0, '1988': 890000.0, '1989': 872000.0, '1990': 1090000.0, '1991': 1220000.0, '1992': 1180000.0, '1993': 1110000.0, '1994': 1125000.0, '1995': 1103000.0, '1996': 1123400.0, '1997': 1115700.0, '1998': 1161000.0, '1999': 991700.0, '2000': 1005000.0, '2001': 988000.0, '2002': 984000.0, '2003': 1127000.0, '2004': 1285000.0, '2005': 1306000.0, '2006': 1425600.0, '2007': 1377800.0, '2008': 1403400.0, '2009': 1140408.0, '2010': 1249869.0, '2011': 354055.0, '2012': 1034332.0, '2013': 674645.0, '2014': 341167.0, '2015': 330019.0, '2016': 350100.0, '2017': 792100.0, '2018': None}, {'Indicator': 'Imports Crude Oil', 'Unit': 'Barrels / Day', 'Country': 'Libya', '1980': None, '1981': None, '1982': None, '1983': None, '1984': None, '1985': None, '1986': None, '1987': 400.0, '1988': 400.0, '1989': 13110.0, '1990': 13000.0, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None}, {'Indicator': 'Consumption of Oil Products', 'Unit': 'Barrels / Day', 'Country': 'Libya', '1980': None, '1981': None, '1982': None, '1983': None, '1984': None, '1985': None, '1986': None, '1987': None, '1988': None, '1989': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': 263000.0, '2010': 280000.0, '2011': 182160.0, '2012': 239000.0, '2013': 248000.0, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None}, {'Indicator': 'Consumption of Oil Products', 'Unit': 'Change year to previous year (Percentage)', 'Country': 'Libya', '1980': None, '1981': None, '1982': None, '1983': None, '1984': None, '1985': None, '1986': None, '1987': None, '1988': None, '1989': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': 31.20333773, '2013': 3.76569037656904, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None}, {'Indicator': 'Exports Natural Gas, Pipe', 'Unit': 'Cubic Meters / Year', 'Country': 'Libya', '1980': None, '1981': None, '1982': None, '1983': None, '1984': None, '1985': None, '1986': None, '1987': None, '1988': None, '1989': None, '1990': None, '1991': None, '1992': None, '1993': None, '1994': None, '1995': None, '1996': None, '1997': None, '1998': None, '1999': None, '2000': None, '2001': None, '2002': None, '2003': None, '2004': 500000000.0, '2005': 4490000000.0, '2006': 7690000000.0, '2007': 9200000000.0, '2008': 9870000000.0, '2009': 9890000000.0, '2010': 9970000000.0, '2011': 207390000. ...
# Finished document:  1
